# %% [markdown]
# <a href="https://colab.research.google.com/github/programminghistorian/jekyll/blob/gh-pages/assets/understanding-creating-word-embeddings/understanding-creating-word-embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preparing Your Corpus

# %%
# %pip install gensim
# Out:
# Requirement already satisfied: gensim in /Users/alan/miniconda3/lib/python3.12/site-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/alan/miniconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/alan/miniconda3/lib/python3.12/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/alan/miniconda3/lib/python3.12/site-packages (from gensim) (6.4.0)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /Users/alan/miniconda3/lib/python3.12/site-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /Users/alan/miniconda3/lib/python3.12/site-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/alan/miniconda3/lib/python3.12/site-packages (from gensim) (6.4.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
# A good practice in programming is to place your import statements at the top of your code, and to keep them together

import re                                   # for regular expressions
import os                                   # to look up operating system-based info
import string                               # to do fancy things with strings
import glob                                 # to locate a specific file type
from pathlib import Path                    # to access files in other directories
import gensim                               # to access Word2Vec
from gensim.models import Word2Vec          # to access Gensim's flavor of Word2Vec
import pandas as pd                         # to sort and organize data
import random

# %%
dirpath = r'./recipes' # get file path (you can change this)
file_type = ".txt" # if your data is not in a plain text format, you can change this
filenames = []
data = []

 # this for loop will run through folders and subfolders looking for a specific file type
for root, dirs, files in os.walk(dirpath, topdown=False):
   # look through all the files in the given directory
   for name in files:
       if (root + os.sep + name).endswith(file_type):
           filenames.append(os.path.join(root, name))

# this for loop then goes through the list of files, reads them, and then adds the text to a list
for filename in filenames:
    with open(filename) as file:
        print(filename)
        data.append(file.read()) # read the file and then add it to the list
        file.close() # close the file when you're done
# Out:
# ./recipes/9101_braincakes.txt
# ./recipes/9624_peachleather.txt
# ./recipes/6677_gingerbeer.txt
# ./recipes/9624_capersauce.txt
# ./recipes/9101_toboilgreensandpoke.txt
# ./recipes/9624_milktoast.txt
# ./recipes/9624_mulledwine.txt
# ./recipes/9101_tobaketomatoes.txt
# ./recipes/9624_rhubarbjam.txt
# ./recipes/9624_almondcake.txt
# ./recipes/9624_bishop.txt
# ./recipes/6677_atrifle.txt
# ./recipes/9624_topicklemushroomwhite.txt
# ./recipes/9101_oystersoupanotherway.txt
# ./recipes/9624_pottedbeef.txt
# ./recipes/29982_towarmagoodsizedpieceofbeef.txt
# ./recipes/9624_appleandotherpies.txt
# ./recipes/9624_raspberryjam.txt
# ./recipes/9101_tokeepvegetablesinwinter.txt
# ./recipes/9624_abakedbreadpudding.txt
# ./recipes/6677_preservedpumpkin.txt
# ./recipes/9624_pyramidoftarts.txt
# ./recipes/9624_toboilcodfish.txt
# ./recipes/9624_icelemonade.txt
# ./recipes/29982_fondantpanache.txt
# ./recipes/9624_cheese.txt
# ./recipes/9624_beets.txt
# ./recipes/6677_stewedoysters.txt
# ./recipes/9101_tobakeafreshshad.txt
# ./recipes/6677_fritters.txt
# ./recipes/9101_spicedbeefintheirishstyle.txt
# ./recipes/9624_acustardpudding.txt
# ./recipes/6677_spanishbuns.txt
# ./recipes/9101_gumbosoup.txt
# ./recipes/6677_commonpasteforpies.txt
# ./recipes/9624_eggsauce.txt
# ./recipes/9624_toroastsweet-breads.txt
# ./recipes/9624_preservedpeppers.txt
# ./recipes/9101_acookpigeons.txt
# ./recipes/9624_tobrownflower.txt
# ./recipes/9624_finepuffpaste.txt
# ./recipes/9624_friedcucumbers.txt
# ./recipes/9624_stiltoncheese.txt
# ./recipes/9624_broiledsweetbreads.txt
# ./recipes/9624_chitterlingsorcalfstripe.txt
# ./recipes/9624_clottedcream.txt
# ./recipes/9624_topickleoystersforkeeping.txt
# ./recipes/9101_chickenstewedwithnewcorn.txt
# ./recipes/9624_topreserveginger.txt
# ./recipes/9624_applecompote.txt
# ./recipes/9624_hashedmutton.txt
# ./recipes/9624_kitchinersfishsauce.txt
# ./recipes/9624_radishes.txt
# ./recipes/9101_tomatoomelet.txt
# ./recipes/9624_gooseberryfool.txt
# ./recipes/9624_toroastamiddlingorspringpieceofpork.txt
# ./recipes/9101_beefalamode.txt
# ./recipes/9101_tofryoysters.txt
# ./recipes/9624_macaronisoup.txt
# ./recipes/9624_aboiledplumpudding.txt
# ./recipes/9624_parsley.txt
# ./recipes/9624_gibletsoup.txt
# ./recipes/9624_aboiledricepudding.txt
# ./recipes/9101_oystersauce.txt
# ./recipes/9624_hamsandwiches.txt
# ./recipes/9101_tobakearockfish.txt
# ./recipes/9624_vealcutlets.txt
# ./recipes/9624_milkbiscuit.txt
# ./recipes/9624_lavendercompound_illness.txt
# ./recipes/9101_tostewclams.txt
# ./recipes/9624_bakedshad.txt
# ./recipes/9624_lemonbrandy.txt
# ./recipes/9624_friedperch.txt
# ./recipes/9101_tobakeastuffedlegofveal.txt
# ./recipes/29982_veryfinechocolatecreams.txt
# ./recipes/9101_toboilaturkey.txt
# ./recipes/9624_tobroilbeefsteaks.txt
# ./recipes/9624_achristmasgoosepie.txt
# ./recipes/9101_tomatoes.txt
# ./recipes/9101_tofryclams.txt
# ./recipes/9624_mushrooms.txt
# ./recipes/9624_stewedeggplant.txt
# ./recipes/6677_alamodebeef.txt
# ./recipes/9624_salmonbakedinslices.txt
# ./recipes/9624_tohashaduck.txt
# ./recipes/9624_potatosnow.txt
# ./recipes/9624_almondpudding.txt
# ./recipes/9624_applebutterwithoutcider.txt
# ./recipes/9624_regentspunch.txt
# ./recipes/6677_yeast.txt
# ./recipes/9624_blackcurrantjelly.txt
# ./recipes/9101_oysterspickledanotherway.txt
# ./recipes/9624_waffles.txt
# ./recipes/9624_toroastchesnuts.txt
# ./recipes/9624_blackcake.txt
# ./recipes/29982_kringles.txt
# ./recipes/9101_toroastbeef.txt
# ./recipes/9624_greencornpudding.txt
# ./recipes/9624_commonmuffins.txt
# ./recipes/9624_horseradishvinegar.txt
# ./recipes/9624_wintersquashorcashaw.txt
# ./recipes/9624_commonyeast.txt
# ./recipes/9101_stuffingordressing.txt
# ./recipes/6677_oystersoup.txt
# ./recipes/9624_peachmangoes.txt
# ./recipes/9624_orangemarmalade.txt
# ./recipes/9624_lemonsyrup.txt
# ./recipes/9101_toboilcalfshead.txt
# ./recipes/9624_lardedsweetbreads.txt
# ./recipes/29982_anicelittlebreakfastdish.txt
# ./recipes/9624_preservedlemons.txt
# ./recipes/9624_bolognasausages.txt
# ./recipes/9624_snowballcustard.txt
# ./recipes/9624_frocasseedchickens.txt
# ./recipes/9624_meltedbuttersometimescalleddrawnbutter.txt
# ./recipes/9624_pottedlobster.txt
# ./recipes/9624_todressbeefkidney.txt
# ./recipes/9624_mincedveal.txt
# ./recipes/9624_anniseedcordial.txt
# ./recipes/9101_peas.txt
# ./recipes/6677_bakedapplepudding.txt
# ./recipes/9624_scarletbeans.txt
# ./recipes/9624_calvesfootjelly_illness.txt
# ./recipes/9624_molassespossets_illness.txt
# ./recipes/29982_tuttifrutticandy.txt
# ./recipes/9101_fricasseechickens.txt
# ./recipes/9624_prunepudding.txt
# ./recipes/9624_winesauce.txt
# ./recipes/9101_limabeans.txt
# ./recipes/9624_vermicellisoup.txt
# ./recipes/9624_toroastaham.txt
# ./recipes/9624_preservedtomatas.txt
# ./recipes/6677_doughnuts.txt
# ./recipes/9624_stuffedeggplants.txt
# ./recipes/9624_leadwater_illness.txt
# ./recipes/9624_musquitobites_medicine.txt
# ./recipes/9624_carrotpudding.txt
# ./recipes/9624_topreservescranberries.txt
# ./recipes/9624_strawberryicecream.txt
# ./recipes/9624_noyau.txt
# ./recipes/9624_honeygingercake.txt
# ./recipes/6677_sugarbiscuit.txt
# ./recipes/9101_tokeepcornforwinter.txt
# ./recipes/9624_greenpeassoup.txt
# ./recipes/9101_tobakefowls.txt
# ./recipes/9624_peachkernels.txt
# ./recipes/29982_towarmovercolmutton.txt
# ./recipes/9101_bacondumplings.txt
# ./recipes/9101_tostewoysters.txt
# ./recipes/29982_beefaugratin.txt
# ./recipes/9624_toroastmutton.txt
# ./recipes/29982_soyersfritadella.txt
# ./recipes/9624_quincepudding.txt
# ./recipes/9624_broiledmushrooms.txt
# ./recipes/9101_tofrytomatoes.txt
# ./recipes/9624_toroastaloinpork.txt
# ./recipes/9624_onionspickledwhite.txt
# ./recipes/9624_washingtoncake.txt
# ./recipes/9624_directionsforcuringhamorbacon.txt
# ./recipes/9624_preservedcucumbers.txt
# ./recipes/9624_lemoncustard.txt
# ./recipes/9624_watermuffins.txt
# ./recipes/9624_awelshrabbit.txt
# ./recipes/9624_broiledtomatas.txt
# ./recipes/9624_todresscucumbersraw.txt
# ./recipes/9624_toroastapig.txt
# ./recipes/9624_greenointment_medicine.txt
# ./recipes/9624_seakale.txt
# ./recipes/9101_lettuce.txt
# ./recipes/9101_topotfreshherring.txt
# ./recipes/9624_whitevinegar.txt
# ./recipes/9624_mangoes.txt
# ./recipes/9624_mockturtlesoup.txt
# ./recipes/9624_indianbattercakes.txt
# ./recipes/9624_cidervinegar.txt
# ./recipes/6677_ricecakesforbreakfast.txt
# ./recipes/9624_tostewmushrooms.txt
# ./recipes/9624_pumpkinyeast.txt
# ./recipes/6677_blancmange.txt
# ./recipes/6677_rusk.txt
# ./recipes/9624_kisses.txt
# ./recipes/9624_driedbeans.txt
# ./recipes/9101_chickensfriedinbatter.txt
# ./recipes/6677_batterpudding.txt
# ./recipes/9624_tokeepeggs.txt
# ./recipes/29982_maraschino.txt
# ./recipes/9624_porksteaks.txt
# ./recipes/9624_abroiledindianpudding.txt
# ./recipes/9624_quinssauce.txt
# ./recipes/9624_commonjumbles.txt
# ./recipes/9624_breadsauce.txt
# ./recipes/9101_friedeggs.txt
# ./recipes/9101_toboilrice.txt
# ./recipes/9624_friedpotatoes.txt
# ./recipes/9624_muttonharico.txt
# ./recipes/9101_toboilcabbage.txt
# ./recipes/9101_toboilfreshfish.txt
# ./recipes/9624_porkpie.txt
# ./recipes/9624_jellycake.txt
# ./recipes/6677_frenchalmondcake.txt
# ./recipes/29982_boucheesdesdames.txt
# ./recipes/9624_bakeappledumplings.txt
# ./recipes/9101_ducks.txt
# ./recipes/9624_applericepudding.txt
# ./recipes/29982_pastry.txt
# ./recipes/9624_shrewsburycakes.txt
# ./recipes/6677_floatingisland.txt
# ./recipes/9624_queencake.txt
# ./recipes/9624_vealpatties.txt
# ./recipes/9624_hoecake.txt
# ./recipes/9101_tofryveallambpork.txt
# ./recipes/9624_currantwine.txt
# ./recipes/9624_tripeandoysters.txt
# ./recipes/9101_tomatojellytowatwithroastmeat.txt
# ./recipes/29982_pastrytablets.txt
# ./recipes/9624_peachjelly.txt
# ./recipes/9624_topickleredcabbage.txt

# %%
print("First recipe:")
print(data[0])

print("\n\nThree random recipes:")
random_recipes = random.sample(data, k=3)
for n, recipe in enumerate(random_recipes):
    print(f"\n== Recipe {n+1} ==")
    print(recipe)
# Out:
# First recipe:
# Brain Cakes.
#
# When the head is cloven, take out the brains and clear them of strings,
# beat them up with the yelks of two eggs, some crumbs of bread, pepper,
# salt, fine parsley, a spoonful of cream, and a spoonful of flour; when
# they are well mixed, drop them with a spoon into a frying-pan with a
# little hot butter, and fry them of a light-brown color.
#
#
# Three random recipes:
#
# == Recipe 1 ==
# Pork Stew Pie.
#
# Take small bones and pieces of pork that will not do for sausage; roll
# out some crust with but little shortening; lay in the meat and small
# pieces of crust alternately; sprinkle in flour and seasoning, cover it
# with water, and put on a crust.
#
# == Recipe 2 ==
# RASPBERRY ICE CREAM.
#
# Is made according to the preceding receipt.
#
# == Recipe 3 ==
# To Brown Oysters in their own Juice.
#
# Take a quart of large oysters, wash them in their own juice, drain and
# dip them in the yelk of eggs; heat butter in a frying-pan, and after
# seasoning them with pepper and salt, put them in separately; when they
# are brown on both sides, draw them to one side of the pan; strain the
# liquor, and put it in with a piece of butter and flour enough to
# thicken it.

# %%
def clean_text(text):

    # Cleans the given text using regular expressions to split and lower-cased versions to create
    # a list of tokens for each text.
    # The function accepts a list of texts and returns a list of of lists of tokens

    # lower case
    tokens = re.split(r"[\s\n.]+", text.replace("—", " ").replace("’", ""))
    tokens = [t.lower() for t in tokens]

    # remove punctuation using regular expressions
    # this line of code locates the punctuation within the given text and compiles that punctuation into a single variable
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # this line of code substitutes the punctuation we just compiled with nothing ''
    tokens = [re_punc.sub('', token) for token in tokens]

    # only include tokens that aren't numbers
    tokens = [token for token in tokens if token.isalpha()]
    return tokens

# %%
# clean text from folder of text files, stored in the data variable
data_clean = []
for x in data:
    data_clean.append(clean_text(x))

# %%
# Check that the length of data and the length of data_clean are the same. Both numbers printed should be the same

print(len(data))
print(len(data_clean))
# Out:
# 1034
# 1034

# %%
# check that the first item in data and the first item in data_clean are the same.
# both print statements should print the same word, with the data cleaning function applied in the second one

print(data[0].split()[0])
print(data_clean[0][0])
# Out:
# Brain
# brain

# %%
# check that the last item in data_clean and the last item in data are the same
# both print statements should print the same word, with the data cleaning function applied in the second one

print(data[0].split()[-1])
print(data_clean[0][-1])
# Out:
# color.
# color

# %%
tokens = re.split(r'[ \n]+', data[0])
cleaned_tokens = data_clean[0]
diff = [
    f"before: \"{token}\" - after: \"{cleaned_tokens[n]}\""
    for n, token in enumerate(tokens)
    if token != cleaned_tokens[n]
]
print("\n".join(diff))
# Out:
# before: "Brain" - after: "brain"
# before: "Cakes." - after: "cakes"
# before: "When" - after: "when"
# before: "cloven," - after: "cloven"
# before: "strings," - after: "strings"
# before: "eggs," - after: "eggs"
# before: "bread," - after: "bread"
# before: "pepper," - after: "pepper"
# before: "salt," - after: "salt"
# before: "parsley," - after: "parsley"
# before: "cream," - after: "cream"
# before: "flour;" - after: "flour"
# before: "mixed," - after: "mixed"
# before: "frying-pan" - after: "fryingpan"
# before: "butter," - after: "butter"
# before: "light-brown" - after: "lightbrown"
# before: "color." - after: "color"

# %%
total_tokens = 0
modified_tokens = 0
for n, text in enumerate(data):
    tokens = [
        i
        for i in re.split(r"[\s\n.\d°]+", text.replace("—", " "))
        if i.translate(str.maketrans("", "", string.punctuation)) != ""
    ]
    cleaned_text = data_clean[n]
    total_tokens += len(tokens)

    modified_tokens += len([t for i, t in enumerate(tokens) if t != cleaned_text[i]])

print(f'{modified_tokens*100/total_tokens:.2f}% of the tokens were modified')
# Out:
# 17.11% of the tokens were modified

# %% [markdown]
# ## Model Creation

# %%
# train the model
model = Word2Vec(sentences=data_clean, window=2, min_count=8, workers=8, epochs=5, sg=1)

# save the model
model.save("word2vec.model")

# %%
# load the model

model = Word2Vec.load("word2vec.model")

# %% [markdown]
# ## Analysis ##

# %% [markdown]
# ### Exploratory Queries

# %%
# set the word that we are checking for
word = "milk"

# if that word is in our vocabulary
if word in model.wv.key_to_index:

    # print a statement to let us know
    print("The word %s is in your model vocabulary" % word)

# otherwise, let us know that it isn't
else:
    print("%s is not in your model vocabulary" % word)
# Out:
# The word milk is in your model vocabulary

# %%
# returns a list with the top ten words used in similar contexts to the word "milk"
model.wv.most_similar('milk', topn=10)
# Out:
# [('cream', 0.8604171276092529),
#  ('rich', 0.8426576256752014),
#  ('molasses', 0.818979024887085),
#  ('meal', 0.7470327615737915),
#  ('thickening', 0.7429587244987488),
#  ('claret', 0.7368207573890686),
#  ('lukewarm', 0.7340987324714661),
#  ('gradually', 0.7131146788597107),
#  ('gill', 0.7121384143829346),
#  ('jill', 0.7103051543235779)]

# %%
# returns the top ten most similar words to "recipe" that are dissimilar from "milk"
model.wv.most_similar(positive = ["recipe"], negative=["milk"], topn=10)

# %%
# returns the top ten most similar words to both "recipe" and "milk"
model.wv.most_similar(positive = ["recipe", "milk"], topn=10)

# %%
# returns a cosine similarity score for the two words you provide
model.wv.similarity("milk", "cream")

# %%
# returns a prediction for the other words in a set containing the words "flour," "eggs," and "cream"
model.predict_output_word([ "flour", "eggs", "cream"])

# %%
# displays the number of words in your model's vocabulary
print(len(model.wv))

# %% [markdown]
# ## Validation ##

# %%
dirpath = Path(r".").glob('*.model') #current directory plus only files that end in 'model'
files = dirpath
model_list = [] # a list to hold the actual models
model_filenames = []  # the filepath for the models so we know where they came from

# %%
#this for loop looks for files that end with ".model" loads them, and then adds those to a list
for filename in files:
    # turn the filename into a string and save it to "file_path"
    file_path = str(filename)
    print(file_path)
    # load the model with the file_path
    model = Word2Vec.load(file_path)
    # add the model to our mode_list
    model_list.append(model)
    # add the filepath to the model_filenames list
    model_filenames.append(file_path)

# %%
# set the word that we are checking for
word = "milk"

# if that word is in our vocabulary
if word in model.wv.key_to_index:

    # print a statement to let us know
    print("The word %s is in your model vocabulary" % word)

# otherwise, let us know that it isn't
else:
    print("%s is not in your model vocabulary" % word)

# %%
#test word pairs that we are going to use to evaluate the models
test_words = [("stir", "whisk"),
             ("cream", "milk"),
             ("cake", "muffin"),
             ("jam", "jelly"),
             ("reserve", "save"),
             ("bake", "cook")]

# %%
# these for loops will go through each list, the test word list and the models list,
# and will run all the words through each model
# then the results will be added to a dataframe

# since NumPy 19.0, sometimes working with arrays of conflicting dimensions will throw a deprecation warning
# this warning does not impact the code or the results, so we're going to filter it out
# you can also specify "dtype=object" on the resulting array
# np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# create an empty dataframe with the column headings we need
evaluation_results = pd.DataFrame(columns=['Model', 'Test Words', 'Cosine Similarity'], dtype=object)

# iterate though the model_list
for i in range(len(model_list)):

    # for each model in model_list, test the tuple pairs
    for x in range(len(test_words)):

        # calculate the similarity score for each tuple
        similarity_score = model_list[i].wv.similarity(*test_words[x])

        # create a temporary dataframe with the test results
        df = [model_filenames[i], test_words[x], similarity_score]

        # add the temporary dataframe to our final dataframe
        evaluation_results.loc[x] = df


# save the evaluation_results dataframe as a .csv called "word2vec_model_evaluation.csv" in our current directory
# if you want the .csv saved somewhere specific, include the filepath in the .to_csv() call
evaluation_results.to_csv('word2vec_model_evaluation.csv')

# %% [markdown]
# ## Next Steps
#
# Here are some resources if you would like to learn more about word vectors:
#
# - The Women [Writers Vector Toolkit](https://wwp.northeastern.edu/lab/wwvt/index.html) is a web interface for exploring word vectors, accompanied by glossaries, sources, case studies, and sample assignments. This toolkit includes links to a [GitHub repository with RMD walkthroughs](https://github.com/NEU-DSG/wwp-public-code-share/tree/main/WordVectors) with code for training word2vec models in R, as well as [download and resources on preparing text corpora](https://wwp.northeastern.edu/lab/wwvt/resources/downloads/index.html).
#
# - The [Women Writers Project Resources](https://wwp.northeastern.edu/outreach/resources/index.html) page has guides on: searching your corpus, corpus analysis and preparation, model validation and assessment, and other materials for working with word vectors.
#
# - [Link to other PH tutorial in draft]

# %% [markdown]
# _This walkthrough was written on November 16, 2022 using Python 3.8.3 and Gensim 4.2.0_
